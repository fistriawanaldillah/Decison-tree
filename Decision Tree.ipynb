# %%
import pandas as pd
df = pd.read_csv("DataKaryawan7.csv")
df
# Out:
#               Jurusan           IPK    Company           Gaji
# 0  Teknik Informatika          Baik  Tokopedia         Tinggi
# 1  Teknik Informatika   Sangat Baik     Shopee  Sangat Tinggi
# 2  Teknik Informatika    Cukup Baik       Goto         Sedang
# 3  Teknik Informatika          Baik  Traveloka  Sangat Tinggi
# 4  Teknik Informatika   Sangat Baik     Shopee         Sedang
# 5  Teknik Informatika    Cukup Baik     Blibli         Tinggi
# 6  Teknik Informatika          Baik  Tokopedia         Tinggi
# 7  Teknik Informatika  Lumayan Baik      Gojek         Sedang
# 8  Teknik Informatika          Baik  Bukalapak         Rendah

# %%
inputs = df.drop('Gaji', axis='columns')
target = df['Gaji']

# %%
target
# Out:
# 0           Tinggi
# 1    Sangat Tinggi
# 2           Sedang
# 3    Sangat Tinggi
# 4           Sedang
# 5           Tinggi
# 6           Tinggi
# 7           Sedang
# 8           Rendah
# Name: Gaji, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder #mengubah kategori menjadi angka

# %%
le_Jurusan = LabelEncoder()
le_IPK = LabelEncoder()
le_Company = LabelEncoder()

# %%
inputs ['Jurusan_n'] = le_Jurusan.fit_transform(inputs['Jurusan'])
inputs ['IPK_n'] = le_IPK.fit_transform(inputs['IPK'])
inputs ['Company_n'] = le_Company.fit_transform(inputs['Company'])
inputs
# Out:
#               Jurusan           IPK    Company  Jurusan_n  IPK_n  Company_n
# 0  Teknik Informatika          Baik  Tokopedia          0      0          5
# 1  Teknik Informatika   Sangat Baik     Shopee          0      3          4
# 2  Teknik Informatika    Cukup Baik       Goto          0      1          3
# 3  Teknik Informatika          Baik  Traveloka          0      0          6
# 4  Teknik Informatika   Sangat Baik     Shopee          0      3          4
# 5  Teknik Informatika    Cukup Baik     Blibli          0      1          0
# 6  Teknik Informatika          Baik  Tokopedia          0      0          5
# 7  Teknik Informatika  Lumayan Baik      Gojek          0      2          2
# 8  Teknik Informatika          Baik  Bukalapak          0      0          1

# %%
inputs_n = inputs.drop(['Jurusan', 'IPK', 'Company'], axis='columns')
inputs_n
# Out:
#    Jurusan_n  IPK_n  Company_n
# 0          0      0          5
# 1          0      3          4
# 2          0      1          3
# 3          0      0          6
# 4          0      3          4
# 5          0      1          0
# 6          0      0          5
# 7          0      2          2
# 8          0      0          1

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs_n,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(inputs_n,target)
# Out:
# 0.8888888888888888

# %%
model.predict([[2,2,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Tinggi'], dtype=object)
